# %% [markdown]
# Python language is ideal for 5-minute bars but when moving downtime sub-second time frames this might not be an ideal choice.
# TA-Lib – TA-Lib or Technical Analysis library is an open-source library and is extensively used to perform technical analysis on financial data using technical indicators such as RSI (Relative Strength Index), Bollinger bands, MACD etc.
# Zipline – Zipline is a Python library for trading applications that power the Quantopian service mentioned above. It is an event-driven system that supports both backtesting and live trading.
# Financial data is available on various online websites. This data is also called as time-series data as it is indexed by time (the timescale can be monthly, weekly, daily, 5 minutely, minutely, etc.).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime as dt
import yfinance as yf

# %%
data=yf.download("^NSEI",start="2012-02-01",end="2019-11-1",interval='1wk')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head(15)
# Out:
#               Adj Close        Close         High          Low         Open  \
# Date
# 2012-01-30  5325.850098  5325.850098  5334.850098  5159.000000  5198.149902
# 2012-02-06  5381.600098  5381.600098  5427.750000  5322.950195  5379.450195
# 2012-02-13  5564.299805  5564.299805  5606.700195  5351.399902  5382.100098
# 2012-02-20  5429.299805  5429.299805  5629.950195  5405.899902  5561.899902
# 2012-02-27  5359.350098  5359.350098  5458.799805  5268.149902  5448.100098
# 2012-03-05  5333.549805  5333.549805  5382.049805  5171.450195  5342.549805
# 2012-03-12  5317.899902  5317.899902  5499.399902  5305.000000  5420.100098
# 2012-03-19  5278.200195  5278.200195  5385.950195  5205.649902  5337.350098
# 2012-03-26  5295.549805  5295.549805  5307.100098  5135.950195  5274.350098
# 2012-04-02  5322.899902  5322.899902  5378.750000  5278.799805  5296.350098
# 2012-04-09  5207.450195  5207.450195  5306.750000  5185.399902  5282.500000
# 2012-04-16  5290.850098  5290.850098  5342.450195  5183.500000  5190.600098
# 2012-04-23  5190.600098  5190.600098  5310.549805  5154.299805  5277.399902
# 2012-04-30  5086.850098  5086.850098  5279.600098  5070.600098  5201.450195
# 2012-05-07  4928.899902  4928.899902  5124.750000  4906.149902  5017.799805
#
#             Volume
# Date
# 2012-01-30       0
# 2012-02-06       0
# 2012-02-13       0
# 2012-02-20       0
# 2012-02-27       0
# 2012-03-05       0
# 2012-03-12       0
# 2012-03-19       0
# 2012-03-26       0
# 2012-04-02       0
# 2012-04-09       0
# 2012-04-16       0
# 2012-04-23       0
# 2012-04-30       0
# 2012-05-07       0

# %% [markdown]
# #install yfinance for downloading stock data using
# #pip install yfinance

# %%
data.head()
# Out:
#               Adj Close        Close         High          Low         Open  \
# Date
# 2012-01-30  5325.850098  5325.850098  5334.850098  5159.000000  5198.149902
# 2012-02-06  5381.600098  5381.600098  5427.750000  5322.950195  5379.450195
# 2012-02-13  5564.299805  5564.299805  5606.700195  5351.399902  5382.100098
# 2012-02-20  5429.299805  5429.299805  5629.950195  5405.899902  5561.899902
# 2012-02-27  5359.350098  5359.350098  5458.799805  5268.149902  5448.100098
#
#             Volume
# Date
# 2012-01-30       0
# 2012-02-06       0
# 2012-02-13       0
# 2012-02-20       0
# 2012-02-27       0

# %%
data.tail()
# Out:
#                Adj Close         Close          High           Low  \
# Date
# 2019-09-30  11174.750000  11174.750000  11554.200195  11158.349609
# 2019-10-07  11305.049805  11305.049805  11362.900391  11090.150391
# 2019-10-14  11661.849609  11661.849609  11684.700195  11290.049805
# 2019-10-21  11583.900391  11583.900391  11714.349609  11490.750000
# 2019-10-28  11890.599609  11890.599609  11945.000000  11627.150391
#
#                     Open  Volume
# Date
# 2019-09-30  11491.150391    4000
# 2019-10-07  11196.200195    2700
# 2019-10-14  11335.900391    3300
# 2019-10-21  11661.849609    3100
# 2019-10-28  11627.150391    4000

# %%
plt.figure(figsize=(12,4))
plt.plot(data.Close)
# Out:
# /Users/pankajjadhav/anaconda2/lib/python2.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
data['ma_10']=data.Close.rolling(10).mean()
data['ma_50']=data.Close.rolling(50).mean()
data['ma_200']=data.Close.rolling(200).mean()

# %%
data.head()
# Out:
#               Adj Close        Close         High          Low         Open  \
# Date
# 2012-01-30  5325.850098  5325.850098  5334.850098  5159.000000  5198.149902
# 2012-02-06  5381.600098  5381.600098  5427.750000  5322.950195  5379.450195
# 2012-02-13  5564.299805  5564.299805  5606.700195  5351.399902  5382.100098
# 2012-02-20  5429.299805  5429.299805  5629.950195  5405.899902  5561.899902
# 2012-02-27  5359.350098  5359.350098  5458.799805  5268.149902  5448.100098
#
#             Volume  ma_10  ma_50  ma_200
# Date
# 2012-01-30       0    NaN    NaN     NaN
# 2012-02-06       0    NaN    NaN     NaN
# 2012-02-13       0    NaN    NaN     NaN
# 2012-02-20       0    NaN    NaN     NaN
# 2012-02-27       0    NaN    NaN     NaN

# %%
plt.figure(figsize=(12,4))
plt.plot(data.Close,label='close')
plt.plot(data.ma_10,label='ma_10')
plt.plot(data.ma_10,label='ma_50')
plt.plot(data.ma_10,label='ma_200')
plt.legend()

# %% [markdown]
# # MACD

# %%
#calculating exponential moving average
data['12d_ema']=data.Close.ewm(span=12).mean()
data['26d_ema']=data.Close.ewm(span=26).mean()

# %%
data[['Close','12d_ema','26d_ema']].plot(figsize=(12,4))

# %%
data['macd']=data['12d_ema']-data['26d_ema']

# %%
data['signal']=data.macd.ewm(span=9).mean()

# %%
plt.figure(figsize=(12,4))
plt.plot(data['Close'])

# %%
data[['macd','signal']].plot(figsize=(12,4))

# %% [markdown]
# There are three most commonly used types of moving averages, the simple, weighted and the exponential moving average.

# %% [markdown]
# # Create a trading signal
# When the value of MACD series is greater than signal series then buy, else sell.

# %%
data['trading_signal']=np.where((data['macd']>data['signal'] ),100,-100)

# %%
#plt.figure(figsize=(12,6))
#plt.plot(np.where(abs(data['macd']-data['signal'])>5,1,-1))

# %%
plt.figure(figsize=(12,4))
plt.plot(data['trading_signal'])

# %%
data['macd'].shape
# Out:
# (405,)

# %%
plt.figure(figsize=(20,7))
plt.plot(data['macd'])
plt.plot(data['signal'])
#data[['macd','signal']].plot(figsize=(12,4))
plt.plot(data.index,np.zeros((data['macd'].shape)))
plt.plot(data['trading_signal'])

# %% [markdown]
# # calculate the strategy return

# %%
#calculate returns
data['returns']=data.Close.pct_change()

# %%
data['returns'].head()
# Out:
# Date
# 2012-01-30         NaN
# 2012-02-06    0.010468
# 2012-02-13    0.033949
# 2012-02-20   -0.024262
# 2012-02-27   -0.012884
# Name: returns, dtype: float64

# %%
#calculate stratergy returns
data['strategy_retuns']=data.returns*data.trading_signal.shift(1)

# %%
data.strategy_retuns.head()
# Out:
# Date
# 2012-01-30         NaN
# 2012-02-06   -1.046781
# 2012-02-13    3.394896
# 2012-02-20   -2.426181
# 2012-02-27   -1.288374
# Name: strategy_retuns, dtype: float64

# %%
#cumulative returns
cumulative_returns=(data.strategy_retuns+1).cumprod()-1

# %%
cumulative_returns.head()
# Out:
# Date
# 2012-01-30         NaN
# 2012-02-06   -1.046781
# 2012-02-13   -1.205599
# 2012-02-20   -0.706779
# 2012-02-27   -1.084557
# Name: strategy_retuns, dtype: float64

# %%
cum_ret=data['strategy_retuns'][1:].cumprod()-1

# %%
plt.figure(figsize=(12,6))
plt.plot(cum_ret)
