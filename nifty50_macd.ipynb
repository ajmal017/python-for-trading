# %% [markdown]
# Python language is ideal for 5-minute bars but when moving downtime sub-second time frames this might not be an ideal choice.
# TA-Lib – TA-Lib or Technical Analysis library is an open-source library and is extensively used to perform technical analysis on financial data using technical indicators such as RSI (Relative Strength Index), Bollinger bands, MACD etc.
# Zipline – Zipline is a Python library for trading applications that power the Quantopian service mentioned above. It is an event-driven system that supports both backtesting and live trading.
# Financial data is available on various online websites. This data is also called as time-series data as it is indexed by time (the timescale can be monthly, weekly, daily, 5 minutely, minutely, etc.).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime as dt
import yfinance as yf

# %%
data=yf.download("LT.NS",start="2010-02-01",end="2019-11-1",interval='1mo')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head(15)
# Out:
#                    Open         High         Low        Close   Adj Close  \
# Date
# 2010-02-01   642.088989   966.599976  617.732971   695.244019  569.840576
# 2010-03-01  1053.329956  1113.329956  685.778015  1087.229980  891.122864
# 2010-04-01   729.822021  1103.800049  687.510986   717.799988  588.328186
# 2010-05-01   712.443970   748.755981  655.599976   725.044006  594.265503
# 2010-06-01   723.510986   819.111023  704.443970   803.978027  658.961914
# 2010-07-01   799.822021   866.978027  791.111023   797.466980  653.625305
# 2010-08-01   800.443970   838.443970  783.111023   806.067017  660.674194
# 2010-08-17          NaN          NaN         NaN          NaN         NaN
# 2010-09-01   808.888977  1254.530029  800.888977   912.510986  759.858276
# 2010-10-01   916.000000   942.177979  856.932983   901.244019  750.476135
# 2010-11-01   908.443970  1338.329956  842.111023   866.689026  721.701782
# 2010-12-01   867.556030  1319.329956  852.689026   879.666992  732.508667
# 2011-01-01   882.377991  1108.599976  698.955994   729.377991  607.361389
# 2011-02-01   733.333008   766.666992  649.333008   679.088989  565.485168
# 2011-03-01   685.867004  1080.670044  667.643982   734.177979  611.358276
#
#                 Volume
# Date
# 2010-02-01  63452410.0
# 2010-03-01  84952492.0
# 2010-04-01  50186240.0
# 2010-05-01  73514734.0
# 2010-06-01  64546215.0
# 2010-07-01  58662528.0
# 2010-08-01  42868112.0
# 2010-08-17         NaN
# 2010-09-01  51470558.0
# 2010-10-01  50697951.0
# 2010-11-01  51005048.0
# 2010-12-01  41969723.0
# 2011-01-01  84430515.0
# 2011-02-01  88963751.0
# 2011-03-01  85594892.0

# %% [markdown]
# #install yfinance for downloading stock data using
# #pip install yfinance

# %%
data.head()
# Out:
#                    Open         High         Low        Close   Adj Close  \
# Date
# 2010-02-01   642.088989   966.599976  617.732971   695.244019  569.840576
# 2010-03-01  1053.329956  1113.329956  685.778015  1087.229980  891.122864
# 2010-04-01   729.822021  1103.800049  687.510986   717.799988  588.328186
# 2010-05-01   712.443970   748.755981  655.599976   725.044006  594.265503
# 2010-06-01   723.510986   819.111023  704.443970   803.978027  658.961914
#
#                 Volume
# Date
# 2010-02-01  63452410.0
# 2010-03-01  84952492.0
# 2010-04-01  50186240.0
# 2010-05-01  73514734.0
# 2010-06-01  64546215.0

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-07-24          NaN          NaN          NaN          NaN          NaN
# 2019-08-01  1380.000000  1399.400024  1274.000000  1328.250000  1328.250000
# 2019-09-01  1328.250000  1551.000000  1289.099976  1474.250000  1474.250000
# 2019-10-01  1480.000000  1496.449951  1381.050049  1473.050049  1473.050049
# 2019-11-01  1476.699951  1481.050049  1314.150024  1330.550049  1330.550049
#
#                 Volume
# Date
# 2019-07-24         NaN
# 2019-08-01  61684084.0
# 2019-09-01  66196029.0
# 2019-10-01  48370306.0
# 2019-11-01  64097061.0

# %%
plt.figure(figsize=(12,4))
plt.plot(data.Close)

# %%
data['ma_10']=data.Close.rolling(10).mean()
data['ma_50']=data.Close.rolling(50).mean()
data['ma_200']=data.Close.rolling(200).mean()

# %%
data.head()
# Out:
#                    Open         High         Low        Close   Adj Close  \
# Date
# 2010-02-01   642.088989   966.599976  617.732971   695.244019  569.840576
# 2010-03-01  1053.329956  1113.329956  685.778015  1087.229980  891.122864
# 2010-04-01   729.822021  1103.800049  687.510986   717.799988  588.328186
# 2010-05-01   712.443970   748.755981  655.599976   725.044006  594.265503
# 2010-06-01   723.510986   819.111023  704.443970   803.978027  658.961914
#
#                 Volume  ma_10  ma_50  ma_200
# Date
# 2010-02-01  63452410.0    NaN    NaN     NaN
# 2010-03-01  84952492.0    NaN    NaN     NaN
# 2010-04-01  50186240.0    NaN    NaN     NaN
# 2010-05-01  73514734.0    NaN    NaN     NaN
# 2010-06-01  64546215.0    NaN    NaN     NaN

# %%
plt.figure(figsize=(12,4))
plt.plot(data.Close,label='close')
plt.plot(data.ma_10,label='ma_10')
plt.plot(data.ma_10,label='ma_50')
plt.plot(data.ma_10,label='ma_200')
plt.legend()

# %% [markdown]
# # MACD

# %%
#calculating exponential moving average
data['12d_ema']=data.Close.ewm(span=12).mean()
data['26d_ema']=data.Close.ewm(span=26).mean()

# %%
data[['Close','12d_ema','26d_ema']].plot(figsize=(12,4))

# %%
data['macd']=data['12d_ema']-data['26d_ema']

# %%
data['signal']=data.macd.ewm(span=9).mean()

# %%
plt.figure(figsize=(12,4))
plt.plot(data['Close'])

# %%
data[['macd','signal']].plot(figsize=(12,4))

# %% [markdown]
# There are three most commonly used types of moving averages, the simple, weighted and the exponential moving average.

# %% [markdown]
# # Create a trading signal
# When the value of MACD series is greater than signal series then buy, else sell.

# %%
data['trading_signal']=np.where((data['macd']>data['signal'] ),10,-10)

# %%
#plt.figure(figsize=(12,6))
#plt.plot(np.where(abs(data['macd']-data['signal'])>5,1,-1))

# %%
plt.figure(figsize=(12,4))
plt.plot(data['trading_signal'])

# %%
data['macd'].shape
# Out:
# (131,)

# %%
plt.figure(figsize=(20,7))
plt.plot(data['macd'])
plt.plot(data['signal'])
#data[['macd','signal']].plot(figsize=(12,4))
plt.plot(data.index,np.zeros((data['macd'].shape)))
plt.plot(data['trading_signal'])

# %% [markdown]
# # calculate the strategy return

# %%
#calculate returns
data['returns']=data.Close.pct_change()

# %%
data['returns'].head()
# Out:
# Date
# 2010-02-01         NaN
# 2010-03-01    0.563811
# 2010-04-01   -0.339790
# 2010-05-01    0.010092
# 2010-06-01    0.108868
# Name: returns, dtype: float64

# %%
#calculate stratergy returns
data['strategy_retuns']=data.returns*data.trading_signal.shift(1)

# %%
data.strategy_retuns.head()
# Out:
# Date
# 2010-02-01         NaN
# 2010-03-01   -5.638106
# 2010-04-01   -3.397901
# 2010-05-01   -0.100920
# 2010-06-01   -1.088679
# Name: strategy_retuns, dtype: float64

# %%
#cumulative returns
cumulative_returns=(data.strategy_retuns+1).cumprod()-1

# %%
cumulative_returns.head()
# Out:
# Date
# 2010-02-01          NaN
# 2010-03-01    -5.638106
# 2010-04-01    10.121720
# 2010-05-01     8.999319
# 2010-06-01    -1.886730
# Name: strategy_retuns, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(cumulative_returns)
